# %%
# !pip install transformers
# !pip install easydict
# !pip install --upgrade torch
# !pip install openpyxl
# !pip install nltk
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.7/site-packages (4.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: huggingface-hub==0.0.8 in /opt/conda/lib/python3.7/site-packages (from transformers) (0.0.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.7/site-packages (from transformers) (4.46.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers) (0.10.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (1.18.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers) (20.1)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers) (0.0.45)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from transformers) (1.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (1.25.9)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from packaging->transformers) (1.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (0.15.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.1.0)
# Requirement already satisfied: easydict in /opt/conda/lib/python3.7/site-packages (1.9)
# Requirement already up-to-date: torch in /opt/conda/lib/python3.7/site-packages (1.8.1)
# Requirement already satisfied, skipping upgrade: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch) (3.10.0.0)
# Requirement already satisfied, skipping upgrade: numpy in /opt/conda/lib/python3.7/site-packages (from torch) (1.18.4)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.7/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.1.0)
# Collecting nltk
#   Using cached nltk-3.6.2-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.46.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.7/site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (0.15.1)
# Installing collected packages: nltk
# Successfully installed nltk-3.6.2

# %%
## Experiment Option
from easydict import EasyDict
import torch

opt = EasyDict()
opt.dataset_series = 'SemEval-16' # SemEval-16, sentihood
opt.dataset_domain = 'restaurant' # restaurant / laptop
opt.subtask = 'sub1' # sub1: sentence, sub2: document(full review)
opt.task = 'category' # category, term
opt.num_classes = 3 # negative, positive, neutral, (+ conflict)
opt.max_length = 200
opt.model_name = 'bert_attscore_rnn_add_sep1'
# model_name: {bert_base, bert_attscore, bert_attscore_rnn, bert_attscore_bi_rnn, bert_attscore_rnn_add_asp,
#    bert_attscore_rnn_add_sep1, bert_attscore_rnn_add_sep_both, bert_attscore_forcls_rnn}
opt.pos = False
opt.lastid = False
opt.top_k = 3
opt.valset_ratio = 0.2
opt.batch_size = 16
opt.num_layers = 6
opt.num_epochs = 12
opt.runs = 5
opt.seed = 42
opt.log_step = 100
opt.patience = 5
opt.device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

print(opt.device)
# Out:
# cuda

# %%
import os, sys
# research_root = os.path.join(GDRIVE_HOME, 'research')
# sys.path.append(research_root)

if opt.dataset_series == 'SemEval-16':
    path = 'dataset/{}/semeval16_{}_{}.csv'.format(opt.dataset_series, opt.subtask, opt.dataset_domain)
    path_test = 'dataset/{}/semeval16_{}_{}_test.csv'.format(opt.dataset_series, opt.subtask, opt.dataset_domain)
elif opt.dataset_series == 'sentihood':
    path = 'dataset/{}/sentihood_train.csv'.format(opt.dataset_series)
    path_test = 'dataset/{}/sentihood_test.csv'.format(opt.dataset_series)

import pandas as pd

df_train = pd.read_csv(path)
df_test = pd.read_csv(path_test)

print('length of train set: {:,}'.format(len(df_train)))
print('length of test set: {:,}'.format(len(df_test)))

#df_train.head()
# Out:
# length of train set: 2,507
# length of test set: 859

# %%
if 'attscore' in opt.model_name:
    from data_utils import clean_sentence, preprocess
    df_train = clean_sentence(df=df_train, clean_func=preprocess)
    df_test = clean_sentence(df=df_test, clean_func=preprocess)

# %% [markdown]
# ## Test analysis
# 1. Load model
# 2. Get samples from test set and tokenize
# 3. Predict
# 4. Decode high attention words
# 5. Result DataFrame

# %% [markdown]
# #### Load Model

# %%
opt.model_name
# Out:
# 'bert_attscore_rnn_add_sep1'

# %%
from models.bert_intermediate import *
from models.bert_pos import *
from models.bert_attscores import *

if opt.model_name == 'bert_base':
    model = Bert_Base(opt.num_classes)
elif opt.model_name == 'bert_attscore':
    model = Bert_AttScore(opt=opt, embed_dim=768, fc_hid_dim=128, top_k=3, att_head='all', att_pooling='mean')
elif opt.model_name == 'bert_attscore_rnn':
    model = Bert_AttScore_RNN(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=False,
                              top_k=opt.top_k, att_head='all', att_pooling='gru')
elif opt.model_name == 'bert_attscore_bi_rnn':
    model = Bert_AttScore_RNN(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                              top_k=opt.top_k, att_head='all', att_pooling='gru')
elif opt.model_name == 'bert_attscore_rnn_add_sep1':
    model = Bert_AttScore_RNN_add(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', additional_token='sep1', att_pooling='gru')
elif opt.model_name == 'bert_attscore_rnn_add_sep2':
    model = Bert_AttScore_RNN_add(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', additional_token='sep2', att_pooling='gru')
elif opt.model_name == 'bert_attscore_rnn_add_sep_both':
    model = Bert_AttScore_RNN_add(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', additional_token='sep_both', att_pooling='gru')
elif opt.model_name == 'bert_attscore_rnn_add_asp':
    model = Bert_AttScore_RNN_add(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', additional_token='asp', att_pooling='gru')
elif opt.model_name == 'bert_attscore_rnn_add_cls':
    model = Bert_AttScore_RNN_add(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', additional_token='cls', att_pooling='gru')
elif opt.model_name == 'bert_attscore_forcls_rnn':
    model = Bert_AttScore_forCLS_RNN(opt=opt, embed_dim=768, rnn_hid_dim=256, fc_hid_dim=128, bidirectional=True,
                                 top_k=opt.top_k, att_head='all', att_pooling='gru')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.load_state_dict(torch.load('state_dict/BEST_bert_attscore_rnn_add_sep_SemEval-16_restaurant_val_acc_83.43%'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### Get samples from test set and tokenize

# %%
sample_idx = [7,8, 22,24] + list(range(300,310)) + list(range(560, 576))
print(sample_idx)
# Out:
# [7, 8, 22, 24, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575]

# %%
df_samples = df_test.iloc[sample_idx].reset_index(drop=True)
df_samples
# Out:
#     re_idx                                         idx  \
# 0        7              en_BlueRibbonSushi_478218345:2
# 1        7              en_BlueRibbonSushi_478218345:2
# 2       22             en_PagodaRestaurant_478006817:2
# 3       22             en_PagodaRestaurant_478006817:2
# 4      232                en_MiopostoCaffe_478542920:5
# 5      234                en_MiopostoCaffe_478542920:7
# 6      234                en_MiopostoCaffe_478542920:7
# 7      235               en_Ray'sBoathouse_477775916:0
# 8      236               en_Ray'sBoathouse_477775916:1
# 9      237               en_Ray'sBoathouse_477775916:2
# 10     237               en_Ray'sBoathouse_477775916:2
# 11     237               en_Ray'sBoathouse_477775916:2
# 12     238                   en_OpenSesame_477970937:0
# 13     242                   en_OpenSesame_477970937:4
# 14     435            en_PagodaRestaurant_479983203:20
# 15     436              en_BlueRibbonSushi_478219459:0
# 16     437              en_BlueRibbonSushi_478219459:1
# 17     437              en_BlueRibbonSushi_478219459:1
# 18     437              en_BlueRibbonSushi_478219459:1
# 19     437              en_BlueRibbonSushi_478219459:1
# 20     438              en_BlueRibbonSushi_478219459:2
# 21     438              en_BlueRibbonSushi_478219459:2
# 22     439              en_BlueRibbonSushi_478219459:3
# 23     440   en_ParkChaletGardenRestaurant_477778211:0
# 24     440   en_ParkChaletGardenRestaurant_477778211:0
# 25     440   en_ParkChaletGardenRestaurant_477778211:0
# 26     444   en_ParkChaletGardenRestaurant_477778211:4
# 27     447   en_ParkChaletGardenRestaurant_477778211:7
# 28     449   en_ParkChaletGardenRestaurant_477778211:9
# 29     450  en_ParkChaletGardenRestaurant_477778211:10
#
#                                              sentence  \
# 0          It has great sushi and even better service
# 1          It has great sushi and even better service
# 2   The lemon chicken tasted like sticky sweet don...
# 3   The lemon chicken tasted like sticky sweet don...
# 4   The servers behind the counter are always frie...
# 5   It's a great place to enjoy food and meet friends
# 6   It's a great place to enjoy food and meet friends
# 7                                        Old Reliable
# 8    After 12 years in Seattle Ray's rates as the ...
# 9   Great food spectacular location and friendly s...
# 10  Great food spectacular location and friendly s...
# 11  Great food spectacular location and friendly s...
# 12                                   Enjoyed the food
# 13                                         I liked it
# 14  it is sad there is not many people who frequen...
# 15                                   Chintzy portions
# 16   The sushi here is perfectly good but for $5 a...
# 17   The sushi here is perfectly good but for $5 a...
# 18   The sushi here is perfectly good but for $5 a...
# 19   The sushi here is perfectly good but for $5 a...
# 20  We easily spent more than $40 per person (not ...
# 21  We easily spent more than $40 per person (not ...
# 22  I'm astonished that this restaurant is categor...
# 23                    Terrible service food ok pricey
# 24                    Terrible service food ok pricey
# 25                    Terrible service food ok pricey
# 26  We put out name down and although there were o...
# 27  We went back to the restaurant and low and beh...
# 28                           None that I can think of
# 29  We put in our order and although we ordered 4 ...
#
#                     category  polarity                      target  from   to
# 0               FOOD#QUALITY  positive                       sushi    13   18
# 1            SERVICE#GENERAL  positive                     service    35   42
# 2               FOOD#QUALITY  negative               lemon chicken     4   17
# 3         FOOD#STYLE_OPTIONS  negative         honey walnut prawns    58   77
# 4            SERVICE#GENERAL  positive  servers behind the counter     4   30
# 5               FOOD#QUALITY  positive                        food    28   32
# 6   RESTAURANT#MISCELLANEOUS  positive                       place    13   18
# 7         RESTAURANT#GENERAL  positive                         NaN     0    0
# 8         RESTAURANT#GENERAL  positive                       Ray's    28   33
# 9               FOOD#QUALITY  positive                        food     6   10
# 10          LOCATION#GENERAL  positive                    location    24   32
# 11           SERVICE#GENERAL  positive                     service    47   54
# 12              FOOD#QUALITY  positive                        food    12   16
# 13        RESTAURANT#GENERAL  positive                         NaN     0    0
# 14        RESTAURANT#GENERAL  positive                         NaN     0    0
# 15        FOOD#STYLE_OPTIONS  negative                    portions     8   16
# 16              FOOD#QUALITY  positive                       sushi     6   11
# 17         RESTAURANT#PRICES  negative                  restaurant   164  174
# 18        FOOD#STYLE_OPTIONS  negative                       sushi     6   11
# 19               FOOD#PRICES  negative                       sushi     6   11
# 20         RESTAURANT#PRICES  negative                         NaN     0    0
# 21        FOOD#STYLE_OPTIONS  negative                         NaN     0    0
# 22         RESTAURANT#PRICES  negative                  restaurant    25   35
# 23           SERVICE#GENERAL  negative                     service     9   16
# 24              FOOD#QUALITY   neutral                        food    18   22
# 25         RESTAURANT#PRICES  negative                         NaN     0    0
# 26           SERVICE#GENERAL  negative                         NaN     0    0
# 27           SERVICE#GENERAL  negative                         NaN     0    0
# 28           SERVICE#GENERAL  negative                         NaN     0    0
# 29           SERVICE#GENERAL  negative                         NaN     0    0

# %%
#df_samples = df_test.sample(30).reset_index(drop=True)
from data_utils import Category_Classification_Dataset as Dataset
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
#trainset = Dataset(df=df_train, tokenizer=tokenizer, opt=opt, pos_encoding=False)
samples = Dataset(df=df_samples, tokenizer=tokenizer, opt=opt, pos_encoding=False)

from torch.utils.data import DataLoader
sample_loader = DataLoader(dataset=samples, batch_size=30, shuffle=False)
iter_sample = iter(sample_loader).next()
print(len(iter_sample['input_ids']))
# Out:
# sentihood: False
# 30 samples in this dataset
# 30

# %% [markdown]
# #### Predict

# %%
output, top_k_idx = model(iter_sample['input_ids'].squeeze(1), iter_sample['attention_masks'].squeeze(1),
                         iter_sample['token_type_ids'].squeeze(1))
predicted = torch.argmax(output, axis=1)
labels = iter_sample['labels']

correct = (predicted == labels).tolist()
labels = labels.tolist()
predicted = predicted.tolist()

# %% [markdown]
# #### Decode high attention words

# %%
high_tokens = list()
for tokens, idx in zip(iter_sample['input_ids'].squeeze(1), top_k_idx):
    high_tokens.append(tokens.squeeze(0)[idx])

words = [tokenizer.decode(tokens) for tokens in high_tokens]

# %% [markdown]
# #### Result DataFrame

# %%
map_result = {0: 'negative', 1: 'positive', 2: 'neutral'}
predict = [map_result[i] for i in predicted]
truth = [map_result[i] for i in labels]

result_dict = {'sentence': df_samples['sentence'], 'aspect': df_samples['category'],
              'high_atts': words, 'truth': truth, 'predict': predict, 'correct': correct}

df = pd.DataFrame(result_dict)
df
# Out:
#                                              sentence  \
# 0          It has great sushi and even better service
# 1          It has great sushi and even better service
# 2   The lemon chicken tasted like sticky sweet don...
# 3   The lemon chicken tasted like sticky sweet don...
# 4   The servers behind the counter are always frie...
# 5   It's a great place to enjoy food and meet friends
# 6   It's a great place to enjoy food and meet friends
# 7                                        Old Reliable
# 8    After 12 years in Seattle Ray's rates as the ...
# 9   Great food spectacular location and friendly s...
# 10  Great food spectacular location and friendly s...
# 11  Great food spectacular location and friendly s...
# 12                                   Enjoyed the food
# 13                                         I liked it
# 14  it is sad there is not many people who frequen...
# 15                                   Chintzy portions
# 16   The sushi here is perfectly good but for $5 a...
# 17   The sushi here is perfectly good but for $5 a...
# 18   The sushi here is perfectly good but for $5 a...
# 19   The sushi here is perfectly good but for $5 a...
# 20  We easily spent more than $40 per person (not ...
# 21  We easily spent more than $40 per person (not ...
# 22  I'm astonished that this restaurant is categor...
# 23                    Terrible service food ok pricey
# 24                    Terrible service food ok pricey
# 25                    Terrible service food ok pricey
# 26  We put out name down and although there were o...
# 27  We went back to the restaurant and low and beh...
# 28                           None that I can think of
# 29  We put in our order and although we ordered 4 ...
#
#                       aspect                  high_atts     truth   predict  \
# 0               FOOD#QUALITY       great better service  positive  positive
# 1            SERVICE#GENERAL          has great service  positive  positive
# 2               FOOD#QUALITY              they not good  negative  negative
# 3         FOOD#STYLE_OPTIONS                 ##were not  negative  negative
# 4            SERVICE#GENERAL             are always and  positive  positive
# 5               FOOD#QUALITY              it great food  positive  positive
# 6   RESTAURANT#MISCELLANEOUS            s great friends  positive  positive
# 7         RESTAURANT#GENERAL           old old reliable  positive  negative
# 8         RESTAURANT#GENERAL               as always to  positive  positive
# 9               FOOD#QUALITY    great location friendly  positive  positive
# 10          LOCATION#GENERAL     great spectacular keep  positive  positive
# 11           SERVICE#GENERAL         great and friendly  positive  positive
# 12              FOOD#QUALITY           enjoyed the food  positive  positive
# 13        RESTAURANT#GENERAL                 i liked it  positive  positive
# 14        RESTAURANT#GENERAL               they are one  positive  positive
# 15        FOOD#STYLE_OPTIONS             ##tzy portions  negative  positive
# 16              FOOD#QUALITY  perfectly good moderately  positive  positive
# 17         RESTAURANT#PRICES                  but nyc )  negative  positive
# 18        FOOD#STYLE_OPTIONS            or moderately (  negative  positive
# 19               FOOD#PRICES                    but ( )  negative  negative
# 20         RESTAURANT#PRICES                we and were  negative  negative
# 21        FOOD#STYLE_OPTIONS            not were hungry  negative  negative
# 22         RESTAURANT#PRICES          ' this restaurant  negative  negative
# 23           SERVICE#GENERAL        terrible service ok  negative  negative
# 24              FOOD#QUALITY           terrible food ok   neutral  negative
# 25         RESTAURANT#PRICES          terrible ok price  negative  negative
# 26           SERVICE#GENERAL                 and were '  negative  negative
# 27           SERVICE#GENERAL              low behold we  negative  negative
# 28           SERVICE#GENERAL                  that i of  negative  negative
# 29           SERVICE#GENERAL                   in 'with  negative  negative
#
#     correct
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24    False
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True

# %% [markdown]
# #### Samples

# %%
def check_att(result_df, idx):
    print('Sentence: ', result_df.iloc[idx].sentence)
    print('Aspect: ', result_df.iloc[idx].aspect)
    print('High_att_words: ', result_df.iloc[idx].high_atts)
    print('Predicted: {} | Truth: {}'.format(result_df.iloc[idx].predict, result_df.iloc[idx].truth))

# %%
check_att(df, 16)
# Out:
# Sentence:   The sushi here is perfectly good but for $5 a piece either the slices of fish should be larger or there should be no pretense that this is a moderately priced restaurant (even for NYC)
# Aspect:  FOOD#QUALITY
# High_att_words:  perfectly good moderately
# Predicted: positive | Truth: positive

# %%
check_att(df, 19)
# Out:
# Sentence:   The sushi here is perfectly good but for $5 a piece either the slices of fish should be larger or there should be no pretense that this is a moderately priced restaurant (even for NYC)
# Aspect:  FOOD#PRICES
# High_att_words:  but ( )
# Predicted: negative | Truth: negative

# %%
check_att(df, 2)
# Out:
# Sentence:  The lemon chicken tasted like sticky sweet donuts and the honey walnut prawns the few they actually give youwere not good
# Aspect:  FOOD#QUALITY
# High_att_words:  they not good
# Predicted: negative | Truth: negative

# %%
check_att(df, 3)
# Out:
# Sentence:  The lemon chicken tasted like sticky sweet donuts and the honey walnut prawns the few they actually give youwere not good
# Aspect:  FOOD#STYLE_OPTIONS
# High_att_words:  ##were not
# Predicted: negative | Truth: negative
